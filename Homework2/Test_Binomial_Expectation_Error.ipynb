# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns 
import math

# %%
def InrangeProbability(b,n,p,size,error):
    count = 0
    exp = n*p
    ceil = math.ceil(exp*(1+error))
    floor = math.floor(exp*(1-error))
    for x in b:
        if (x <= ceil) and (x >= floor):
            count+=1
    #print(count)
    return count/size

# %%
def DoSimulation(n,p,e):
    size = 100000
    b = random.binomial(n,p,size)
    print(b)
    sns.distplot(b)
    plt.show()
    answer = InrangeProbability(b,n,p,size,e)
    print(answer)
    return answer

# %%
b00 = round(DoSimulation(500,0.7,0.01),4)
b00
# Out:
# [347 364 357 ... 353 355 343]
# 0.33963
# 0.3396

# %%
b10 = round(DoSimulation(4000,0.7,0.01),4)
b10
# Out:
# [2811 2837 2778 ... 2781 2791 2792]
# 0.67294
# 0.6729

# %%
b20 = round(DoSimulation(20000,0.7,0.01),4)
b20
# Out:
# [14029 13979 14085 ... 14049 13937 14066]
# 0.97075
# 0.9708

# %%
b01 = round(DoSimulation(500,0.5,0.01),4)
b01
# Out:
# [242 223 259 ... 263 239 261]
# 0.24403
# 0.244

# %%
b11 = round(DoSimulation(4000,0.5,0.01),4)
b11
# Out:
# [2063 2007 2012 ... 2041 2006 1990]
# 0.48537
# 0.4854

# %%
b21 = round(DoSimulation(20000,0.5,0.01),4)
b21
# Out:
# [10028  9937 10021 ... 10046 10005 10072]
# 0.84537
# 0.8454

# %%
fig = plt.figure(dpi=80)
ax = fig.add_subplot(1,1,1)

col_labels = ['p=0.7,e=0.01','p=0.5,e=0.01']
row_labels = ['n=500','n=4000','n=20000']
cell_data = [[b00,b01],[b10,b11],[b20,b21]]

table = ax.table(cellText=cell_data,rowLabels=row_labels, colLabels=col_labels, cellLoc='center',loc='center')
table.set_fontsize(14)
table.scale(1,4)
ax.axis('off')
plt.show()
