# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns 
import math

# %%
def InrangeProbability(b,n,p,size,error):
    count = 0
    exp = n*p
    ceil = math.ceil(exp*(1+error))
    floor = math.floor(exp*(1-error))
    for x in b:
        if (x <= ceil) and (x >= floor):
            count+=1
    #print(count)
    return count/size

# %%
def DoSimulation(n,p,e):
    size = 100000
    b = random.binomial(n,p,size)
    print(b)
    sns.distplot(b)
    plt.show()
    answer = InrangeProbability(b,n,p,size,e)
    print(answer)
    return answer

# %%
b00 = round(DoSimulation(100,0.25,0.01),4)
b00
# Out:
# [27 26 28 ... 21 28 32]
# 0.27176
# 0.2718

# %%
b10 = round(DoSimulation(3000,0.25,0.01),4)
b10
# Out:
# [724 777 766 ... 748 754 731]
# 0.27877
# 0.2788

# %%
b20 = round(DoSimulation(50000,0.25,0.01),4)
b20
# Out:
# [12364 12545 12595 ... 12399 12329 12607]
# 0.80557
# 0.8056

# %%
b01 = round(DoSimulation(100,0.05,0.05),4)
b01
# Out:
# [ 7  4  7 ... 10  7  4]
# 0.508
# 0.508

# %%
b11 = round(DoSimulation(3000,0.05,0.05),4)
b11
# Out:
# [151 153 138 ... 153 155 150]
# 0.52506
# 0.5251

# %%
b21 = round(DoSimulation(50000,0.05,0.05),4)
b21
# Out:
# [2519 2465 2449 ... 2422 2556 2524]
# 0.98942
# 0.9894

# %%
fig = plt.figure(dpi=80)
ax = fig.add_subplot(1,1,1)

col_labels = ['p=0.7,e=0.01','p=0.5,e=0.01']
row_labels = ['n=500','n=4000','n=20000']
cell_data = [[b00,b01],[b10,b11],[b20,b21]]

table = ax.table(cellText=cell_data,rowLabels=row_labels, colLabels=col_labels, cellLoc='center',loc='center')
table.set_fontsize(14)
table.scale(1,4)
ax.axis('off')
plt.show()
